# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprakash2109/Data_analyst/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/HR_capstone_dataset.csv")

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (14999, 10)

# %%
df["Department"].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
df["salary"].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        11991.000000     11991.000000    11991.000000
# mean             0.629658         0.716683        3.802852
# std              0.241070         0.168343        1.163238
# min              0.090000         0.360000        2.000000
# 25%              0.480000         0.570000        3.000000
# 50%              0.660000         0.720000        4.000000
# 75%              0.820000         0.860000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          11991.000000        11991.000000   11991.000000  11991.000000
# mean             200.473522            3.364857       0.154282      0.166041
# std               48.727813            1.330240       0.361234      0.372133
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
sns.countplot(data=df, x="number_project")
# Out:
# <Axes: xlabel='number_project', ylabel='count'>

# %%
sns.countplot(data=df, x="number_project", hue="left")
# Out:
# <Axes: xlabel='number_project', ylabel='count'>

# %%
df[df["number_project"] == 3]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 45                   0.84             0.74               3
# 47                   0.57             0.70               3
# 108                  0.71             0.87               3
# 127                  0.70             0.89               3
# 281                  0.27             0.56               3
# ...                   ...              ...             ...
# 11992                0.62             0.85               3
# 11994                0.22             0.94               3
# 11995                0.90             0.55               3
# 11997                0.85             0.54               3
# 11998                0.33             0.65               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 45                      182                   4              0     1
# 47                      273                   6              0     1
# ...

# %%
sns.countplot(data=df,x="time_spend_company",hue="left")
# Out:
# <Axes: xlabel='time_spend_company', ylabel='count'>

# %%
sns.countplot(data=df,x="Department",hue="left")
plt.xticks(rotation = 90)
plt.show()

# %%
ax = sns.countplot(data=df,x="Department",hue="left")
plt.xticks(rotation = 90)
for x in ax.containers:
  ax.bar_label(x)
plt.show()

# %%
sns.countplot(data=df,x="Department",hue="salary")
plt.xticks(rotation = 90)
plt.show()

# %%
ax = sns.countplot(data=df,x="salary",hue="left")
for x in ax.containers:
  ax.bar_label(x)
plt.show()

# %%
low_pct = (1174/4566)*100
low_pct
# Out:
# 25.711782742006132

# %%
high_pct = (48/942)*100
high_pct
# Out:
# 5.095541401273886

# %%
medium_pet = (769/4492)*100
medium_pet
# Out:
# 17.1193232413179

# %%
ax = sns.countplot(data=df,x="Work_accident",hue="left")
for x in ax.containers:
  ax.bar_label(x)
plt.show()

# %%
work_conflicts = (105/1745)*100
work_conflicts
# Out:
# 6.017191977077363

# %%
no_work_conflicts = (1886/8255)*100
no_work_conflicts
# Out:
# 22.846759539672927
