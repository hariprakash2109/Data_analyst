# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprakash2109/Data_analyst/blob/main/data_analyast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name="Calories"
s
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: Calories, dtype: int64

# %%
s[0]
# Out:
# np.int64(10)

# %%
s[0:2]
# Out:
# apple     10
# banana    20
# Name: Calories, dtype: int64

# %%
s[2:4]
# Out:
# grapes    30
# orange    40
# Name: Calories, dtype: int64

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
index = ["apple","banana","grapes","orange","strawberry"]

# %%
s.index = index
s
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: Calories, dtype: int64

# %%
s['grapes']
# Out:
# np.int64(30)

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.loc['grapes']
# Out:
# np.int64(30)

# %%
s['banana':'orange']
# Out:
# banana    20
# grapes    30
# orange    40
# Name: Calories, dtype: int64

# %%
fruit_protein = {
    "Avocado": 2.0,
    "Guava": 2.6,
    "Blackberries": 2.0,
    "Oranges": 0.9,
    "Banana": 1.1,
    "Apples": 0.3,
    "Kiwi": 1.1,
    "Pomegranate": 1.7,
    "Mango": 0.8,
    "Cherries": 1.0
}

# %%
s2 = pd.Series(fruit_protein)
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# dtype: float64

# %%
s3 = pd.Series(fruit_protein, name="Protein")
s3
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
s3>1
# Out:
# Avocado          True
# Guava            True
# Blackberries     True
# Oranges         False
# Banana           True
# Apples          False
# Kiwi             True
# Pomegranate      True
# Mango           False
# Cherries        False
# Name: Protein, dtype: bool

# %%
s3[s3>1]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Banana          1.1
# Kiwi            1.1
# Pomegranate     1.7
# Name: Protein, dtype: float64

# %%
[(s3>0.5) & (s3<2)]
# Out:
# [Avocado         False
#  Guava           False
#  Blackberries    False
#  Oranges          True
#  Banana           True
#  Apples          False
#  Kiwi             True
#  Pomegranate      True
#  Mango            True
#  Cherries         True
#  Name: Protein, dtype: bool]
