# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprakash2109/Data_analyst/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="hari"
print(name)
# Out:
# hari
# 'Hari'

# %%
person = ["Hari",25,6.3]
person
# Out:
# ['Hari', 25, 6.3]

# %%
person = ["Hari",25,6.3]
person[2]=6.4
person
# Out:
# ['Hari', 25, 6.4]

# %%
person = ["Hari",25,6.3]
person.append("Swimming")
person
# Out:
# ['Hari', 25, 6.3, 'Swimming']

# %%
person.remove("Swimming")
person
# Out:
# ['Hari', 25, 6.3]

# %%
height=6.4
type(height)
# Out:
# float

# %%
person = ["Hari",25,6.3]
person[0]
# Out:
# 'Hari'

# %%
age=25
type(age)
# Out:
# int

# %%
coord=(10,20)
type(coord)
# Out:
# tuple

# %%
coord[0]
# Out:
# 10

# %%
coord[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2202279541.py in <cell line: 0>()
# ----> 1 coord[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
p={"name":"Hari","age":22,"Height":6.4}

# %%
type(p)
# Out:
# dict

# %%
p["name"]
# Out:
# 'Hari'

# %%
p["name"]="Prakash"
p
# Out:
# {'name': 'Prakash', 'age': 22, 'Height': 6.4}

# %%
p["Sport"]="Swimming"
p
# Out:
# {'name': 'Prakash', 'age': 22, 'Height': 6.4, 'Sport': 'Swimming'}

# %%
s=0
for i in range(1,11):
  s+=i
print(s)
# Out:
# 55

# %%
s=0
i=0
while(i<6):
  s+=i
  i+=1
print(s)
# Out:
# 15
